# %%
# 导入模块
from revenue_forecasting import run_revenue_forecasting
csv_file_path = "/Users/warroom/Desktop/Time_series_forecasting/data/raw/ialp_raw.csv" 
results = run_revenue_forecasting(csv_file_path)
# Out:
# === 开始第一阶段：时间序列预测 - 收入基线分析 ===
#
# 1. 加载数据...
# ✅ 成功加载数据，共 10569 行
#
# 数据列名:
# ['Year_Month', 'Date', 'Month', 'Year', 'Channel', 'Location', 'Format', 'Ad_Name', 'Full_Ad_Name', 'Purchases', 'Revenue', 'Impressions', 'Ad_Clicks', 'Spend', 'Leads']
#
# 数据时间范围: 2022-01-01 到 2025-07-31
# 数据形状: (10569, 15)
#
# === 数据划分信息 ===
# 训练数据期间: 2022-01 到 2024-12
# 测试数据期间: 2025-01 到 2025-07
# 训练数据点数: 36, 测试数据点数: 7
#
# 2. 探索性数据分析...
# 16:14:28 - cmdstanpy - INFO - Chain [1] start processing
# === 收入趋势统计摘要 ===
# 训练期平均月收入: $186,310
# 收入标准差: $73,611
# 最高月收入: $322,503 (2023-06)
# 最低月收入: $72,308 (2022-09)
#
# 3. 执行Prophet预测...
# 训练Prophet模型...
# 16:14:29 - cmdstanpy - INFO - Chain [1] done processing
# 生成预测...
#
# 4. 评估预测效果...
#
# === 预测效果评估 (基于2025年实际数据) ===
# 平均绝对误差 (MAE): $97,820
# 均方根误差 (RMSE): $130,591
# 平均绝对百分比误差 (MAPE): 22.9%
#
# 5. 可视化预测结果...
# 6. 生成预测结果表...
#
# === 未来12个月收入预测 ===
# Year_Month  Pessimistic  Realistic  Optimistic
#    2025-01       172960     208364      243772
# ...
